# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import pickle

df = pd.read_csv("homeprices.csv")

X = df[['area']]  # DataFrame (important)
y = df['price']

model = LinearRegression()
model.fit(X, y)

print("Weight:", model.coef_)
print("Bias:", model.intercept_)

# SAVE MODEL using Pickle
with open("house_price_model.pkl", "wb") as file:
    pickle.dump(model, file)

print("Model saved using pickle")

# LOAD MODEL using Pickle
with open("house_price_model.pkl", "rb") as file:
    loaded_model = pickle.load(file)

print("Model loaded successfully")

# Prediction 
area_value = 5000
input_data = pd.DataFrame([[area_value]], columns=['area'])

prediction = loaded_model.predict(input_data)

print(f"Predicted price for {area_value} sqft:", prediction[0])
# Out:
# Weight: [135.78767123]
# Bias: 180616.43835616432
# Model saved using pickle
# Model loaded successfully
# Predicted price for 5000 sqft: 859554.7945205481
